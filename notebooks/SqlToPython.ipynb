# %%
from sqlalchemy import create_engine
import urllib

# Build connection string — REPLACE 'localhost\SQLEXPRESS' with YOUR server name
params = urllib.parse.quote_plus(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=localhost\\SQLEXPRESS;"
    "DATABASE=RetailDB;"
    "Trusted_Connection=yes;"
)

engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

# Push DataFrame to SQL Server
df.to_sql('sales', engine, if_exists='replace', index=False, chunksize=1000)

print("✓ Data loaded to SQL Server")
